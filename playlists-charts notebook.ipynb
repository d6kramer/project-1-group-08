# %% [markdown]
# Starter file for Project 1 - need to load in Spotify CSV!

# %%
# Import Dependencies
import pandas as pd
from pathlib import Path

# %%
csv_path = Path("Resources/spotify-2023.csv")

spotify_df = pd.read_csv(csv_path, encoding='iso-8859-1')

#Basic Dataframe with all information
spotify_df.head()
# Out:
#                             track_name   Artist Name 1 Artist Name 2  \
# 0  Seven (feat. Latto) (Explicit Ver.)           Latto     Jung Kook
# 1                                 LALA     Myke Towers           NaN
# 2                              vampire  Olivia Rodrigo           NaN
# 3                         Cruel Summer    Taylor Swift           NaN
# 4                       WHERE SHE GOES       Bad Bunny           NaN
#
#   Artist Name 3 Artist Name 4 Artist Name 5 Artist Name 6 Artist Name 7  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   Artist Name 8  artist_count  ...  bpm  key   mode  danceability_%  \
# ...

# %%
#Breakdown of columns and verification of null entries. None found.
spotify_df['track_name'] = spotify_df['track_name'].astype("string")
spotify_df['Artist Name 1'] = spotify_df['Artist Name 1'].astype("string")
spotify_df['Artist Name 2'] = spotify_df['Artist Name 2'].astype("string")
spotify_df['Artist Name 3'] = spotify_df['Artist Name 3'].astype("string")
spotify_df['Artist Name 4'] = spotify_df['Artist Name 4'].astype("string")
spotify_df['Artist Name 5'] = spotify_df['Artist Name 5'].astype("string")
spotify_df['Artist Name 6'] = spotify_df['Artist Name 6'].astype("string")
spotify_df['Artist Name 7'] = spotify_df['Artist Name 7'].astype("string")
spotify_df['Artist Name 8'] = spotify_df['Artist Name 8'].astype("string")

spotify_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 31 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    string
#  1   Artist Name 1         953 non-null    string
#  2   Artist Name 2         367 non-null    string
#  3   Artist Name 3         111 non-null    string
#  4   Artist Name 4         27 non-null     string
#  5   Artist Name 5         12 non-null     string
#  6   Artist Name 6         7 non-null      string
#  7   Artist Name 7         4 non-null      string
#  8   Artist Name 8         2 non-null      string
#  9   artist_count          953 non-null    int64
#  10  released_year         953 non-null    int64
#  11  released_month        953 non-null    int64
#  12  released_day          953 non-null    int64
#  13  in_spotify_playlists  953 non-null    int64
#  14  in_spotify_charts     953 non-null    int64
# ...

# %%
#General idea of unique entries per column - some interesting baseline data to start exploring.
spotify_df.nunique()
# Out:
# track_name              941
# Artist Name 1           458
# Artist Name 2           244
# Artist Name 3            99
# Artist Name 4            27
# Artist Name 5            12
# Artist Name 6             7
# Artist Name 7             4
# Artist Name 8             2
# artist_count              8
# released_year            50
# released_month           12
# released_day             31
# in_spotify_playlists    879
# in_spotify_charts        82
# streams                 949
# in_apple_playlists      234
# in_apple_charts         172
# in_deezer_playlists     348
# in_deezer_charts         34
# in_shazam_charts        198
# bpm                     124
# key                      11
# mode                      2
# danceability_%           72
# valence_%                94
# energy_%                 80
# acousticness_%           98
# instrumentalness_%       39
# liveness_%               68
# speechiness_%            48
# dtype: int64

# %%
playlists = spotify_df[["track_name", "streams", "in_spotify_playlists", "in_apple_playlists", "in_deezer_playlists"]]

playlists
# Out:
#                               track_name    streams  in_spotify_playlists  \
# 0    Seven (feat. Latto) (Explicit Ver.)  141381703                   553
# 1                                   LALA  133716286                  1474
# 2                                vampire  140003974                  1397
# 3                           Cruel Summer  800840817                  7858
# 4                         WHERE SHE GOES  303236322                  3133
# ..                                   ...        ...                   ...
# 948                         My Mind & Me   91473363                   953
# 949            Bigger Than The Whole Sky  121871870                  1180
# 950                 A Veces (feat. Feid)   73513683                   573
# 951                        En La De Ella  133895612                  1320
# 952                                Alone   96007391                   782
#
#      in_apple_playlists in_deezer_playlists
# ...

# %%
charts = spotify_df[["track_name", "streams", "in_spotify_charts", "in_apple_charts", "in_deezer_charts", "in_shazam_charts"]]
charts
# Out:
#                               track_name    streams  in_spotify_charts  \
# 0    Seven (feat. Latto) (Explicit Ver.)  141381703                147
# 1                                   LALA  133716286                 48
# 2                                vampire  140003974                113
# 3                           Cruel Summer  800840817                100
# 4                         WHERE SHE GOES  303236322                 50
# ..                                   ...        ...                ...
# 948                         My Mind & Me   91473363                  0
# 949            Bigger Than The Whole Sky  121871870                  0
# 950                 A Veces (feat. Feid)   73513683                  0
# 951                        En La De Ella  133895612                  0
# 952                                Alone   96007391                  2
#
#      in_apple_charts  in_deezer_charts in_shazam_charts
# 0                263                10              826
# ...
